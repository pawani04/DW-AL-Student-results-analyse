# %%
import pandas as pd
import sweetviz as sv

# CSV file eke path eka
csv_path = r"C:\Users\devpa\Documents\2020_al_data_kaggle_upload_new_old_syllabi.csv"

print("Dataset eka load wemin pawathee...")
# Data load kirima
my_dataset = pd.read_csv(csv_path)

print("Profiling summary eka hadamin pawathee...")
# Report eka generate kirima
analysis_summary = sv.analyze(my_dataset)

# Report eka HTML format eken save wela browser eke open weemata
analysis_summary.show_html(filepath="al_data_report.html", open_browser=True)
print("Sarthakai!")
# Out:
# Dataset eka load wemin pawathee...
# Profiling summary eka hadamin pawathee...
#                                              |          | [  0%]   00:00 -> (? left)
# Report al_data_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Sarthakai!

# %%
import pandas as pd

# Data thiyena thana
dataset_location = r"C:\Users\devpa\Documents\2020_al_data_kaggle_upload_new_old_syllabi.csv"

# Dataset eka read karamu
student_data = pd.read_csv(dataset_location)

# Dataset eke pramanaya (rows and columns)
print("SHAPE (Rows saha Columns):", student_data.shape)

# Athulath columns monawada kiyala balamu
print("\nAVAILABLE COLUMNS:")
print(student_data.columns.tolist())

# Palamu peli 5
print("\nFIRST 5 ROWS:")
print(student_data.head())

# Hodu (Null) values thiyenawada balamu
print("\nNULL VALUES COUNT:")
print(student_data.isnull().sum())
# Out:
# SHAPE (Rows saha Columns): (337553, 19)
#
# AVAILABLE COLUMNS:
# ['index', 'stream', 'Zscore', 'district_rank', 'island_rank', 'al_year', 'sub1', 'sub1_r', 'sub2', 'sub2_r', 'sub3', 'sub3_r', 'cgt_r', 'ge_r', 'syllabus', 'birth_day', 'birth_month', 'birth_year', 'gender']
#
# FIRST 5 ROWS:
#    index    stream  Zscore district_rank  island_rank  al_year  \
# 0      0      ARTS  -.3550    4336 (NEW)  64994 (NEW)     2020
# 1      1      ARTS  -.2648    4154 (NEW)  62338 (NEW)     2020
# 2      2  COMMERCE  -.4760    6910 (NEW)  37307 (NEW)     2020
# 3      3  COMMERCE  -.1012    5678 (NEW)  30449 (NEW)     2020
# 4      4  COMMERCE   .6014    3269 (NEW)  17010 (NEW)     2020
#
#                 sub1 sub1_r               sub2 sub2_r        sub3 sub3_r  \
# 0  POLITICAL SCIENCE      S  DANCING(BHARATHA)      C       TAMIL      S
# 1  POLITICAL SCIENCE      S     CARNATIC MUSIC      C       TAMIL      C
# 2          ECONOMICS      S   BUSINESS STUDIES      S  ACCOUNTING      S
# ...
